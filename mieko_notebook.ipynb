# %% [markdown]
# # Project 2

# %%
import pandas as pd

# Read the Excel file into a pandas DataFrame
abortion = pd.read_excel("Abortion-Data.xlsx")
abortion.head()
# Out:
#    U.S. State  % change in abortion rate, 2017-2020  \
# 0     Alabama                                    -6
# 1      Alaska                                     0
# 2     Arizona                                     1
# 3    Arkansas                                     2
# 4  California                                    17
#
#    % change in the no. of abortion clinics, 2017-2020  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                -33
# 4                                                  7
#
#    % change in the no. of abortion providers, 2014-2017  \
# 0                                                -22
# 1                                                -25
# 2                                                 -8
# 3                                                  0
# 4                                                -18
#
#    % of all U.S. abortions, by state of occurrence, 2020  \
# 0                                                0.6
# 1                                                0.1
# 2                                                1.4
# 3                                                0.3
# 4                                               16.6
#
#    % of counties without a known abortion provider, 2014  \
# 0                                                 91
# 1                                                 79
# 2                                                 80
# 3                                                 97
# 4                                                 24
#
#    % of counties without a known clinic, 2020  \
# 0                                          93
# 1                                          87
# 2                                          80
# 3                                          99
# 4                                          38
#
#    % of residents obtaining abortions who traveled out of state for care, 2020  \
# 0                                                 47
# 1                                                  7
# 2                                                  6
# 3                                                 37
# 4                                                  0
#
#    % of women aged 15-44 living in a county without a clinic, 2020  \
# 0                                                 59
# 1                                                 33
# 2                                                 18
# 3                                                 86
# 4                                                  3
#
#    % of women aged 15-44 living in a county without an abortion provider, 2014  \
# 0                                                 58
# 1                                                 17
# 2                                                 19
# 3                                                 77
# 4                                                  1
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   No. of abortions per 1,000 women aged 15–44, by state of occurrence, 2020  \
# 0                                                6.0
# 1                                                8.6
# 2                                                9.3
# 3                                                5.6
# 4                                               19.2
#
#    No. of abortions per 1,000 women aged 15–44, by state of residence, 2020  \
# 0                                                9.5
# 1                                                9.2
# 2                                                9.7
# 3                                                7.8
# 4                                               19.0
#
#   No. of abortions, by state of occurrence, 2020  \
# 0                                           5700
# 1                                           1240
# 2                                          13320
# 3                                           3250
# 4                                         154060
#
#    No. of abortions, by state of residence, 2020  \
# 0                                           9060
# 1                                           1320
# 2                                          13820
# 3                                           4510
# 4                                         152400
#
#    No. of federally funded abortions, 2010  \
# 0                                        9
# 1                                        0
# 2                                        1
# 3                                        0
# 4                                        0
#
#    No. of state funded abortions, 2010  \
# 0                                    0
# 1                                  835
# 2                                   13
# 3                                    0
# 4                                88466
#
#    Reported public expenditures for abortions (in 000s of dollars), federal, 2015  \
# 0                                                 22
# 1                                                  0
# 2                                                 28
# 3                                                  0
# 4                                                  0
#
#   Reported public expenditures for abortions (in 000s of dollars), state, 2015  \
# 0                                                  0
# 1                                                216
# 2                                                 11
# 3                                                  0
# 4                                              32613
#
#    Total no. of publicly funded abortions , 2010  \
# 0                                              9
# 1                                            835
# 2                                             14
# 3                                              0
# 4                                          88466
#
#   Total reported public expenditures for abortions (in 000s of dollars), 2015
# 0                                                 22
# 1                                                216
# 2                                                 40
# 3                                                  0
# 4                                              32613
#
# [5 rows x 31 columns]

# %%
state_results_2024 = {
    "Alabama": "Republican",
    "Alaska": "Republican",
    "Arizona": "Republican",
    "Arkansas": "Republican",
    "California": "Democrat",
    "Colorado": "Democrat",
    "Connecticut": "Democrat",
    "Delaware": "Democrat",
    "District of Columbia": "Democrat",
    "Florida": "Republican",
    "Georgia": "Republican",
    "Hawaii": "Democrat",
    "Idaho": "Republican",
    "Illinois": "Democrat",
    "Indiana": "Republican",
    "Iowa": "Republican",
    "Kansas": "Republican",
    "Kentucky": "Republican",
    "Louisiana": "Republican",
    "Maine": "Democrat",
    "Maryland": "Democrat",
    "Massachusetts": "Democrat",
    "Michigan": "Republican",
    "Minnesota": "Democrat",
    "Mississippi": "Republican",
    "Missouri": "Republican",
    "Montana": "Republican",
    "Nebraska": "Republican",
    "Nevada": "Republican",
    "New Hampshire": "Democrat",
    "New Jersey": "Democrat",
    "New Mexico": "Democrat",
    "New York": "Democrat",
    "North Carolina": "Republican",
    "North Dakota": "Republican",
    "Ohio": "Republican",
    "Oklahoma": "Republican",
    "Oregon": "Democrat",
    "Pennsylvania": "Republican",
    "Rhode Island": "Democrat",
    "South Carolina": "Republican",
    "South Dakota": "Republican",
    "Tennessee": "Republican",
    "Texas": "Republican",
    "Utah": "Republican",
    "Vermont": "Democrat",
    "Virginia": "Democrat",
    "Washington": "Democrat",
    "West Virginia": "Republican",
    "Wisconsin": "Republican",
    "Wyoming": "Republican",
}

# %%
abortion['Election2024'] = abortion['U.S. State'].map(state_results_2024)

# %%
abortion.head()
# Out:
#    U.S. State  % change in abortion rate, 2017-2020  \
# 0     Alabama                                    -6
# 1      Alaska                                     0
# 2     Arizona                                     1
# 3    Arkansas                                     2
# 4  California                                    17
#
#    % change in the no. of abortion clinics, 2017-2020  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                -33
# 4                                                  7
#
#    % change in the no. of abortion providers, 2014-2017  \
# 0                                                -22
# 1                                                -25
# 2                                                 -8
# 3                                                  0
# 4                                                -18
#
#    % of all U.S. abortions, by state of occurrence, 2020  \
# 0                                                0.6
# 1                                                0.1
# 2                                                1.4
# 3                                                0.3
# 4                                               16.6
#
#    % of counties without a known abortion provider, 2014  \
# 0                                                 91
# 1                                                 79
# 2                                                 80
# 3                                                 97
# 4                                                 24
#
#    % of counties without a known clinic, 2020  \
# 0                                          93
# 1                                          87
# 2                                          80
# 3                                          99
# 4                                          38
#
#    % of residents obtaining abortions who traveled out of state for care, 2020  \
# 0                                                 47
# 1                                                  7
# 2                                                  6
# 3                                                 37
# 4                                                  0
#
#    % of women aged 15-44 living in a county without a clinic, 2020  \
# 0                                                 59
# 1                                                 33
# 2                                                 18
# 3                                                 86
# 4                                                  3
#
#    % of women aged 15-44 living in a county without an abortion provider, 2014  \
# 0                                                 58
# 1                                                 17
# 2                                                 19
# 3                                                 77
# 4                                                  1
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   No. of abortions per 1,000 women aged 15–44, by state of residence, 2020  \
# 0                                                9.5
# 1                                                9.2
# 2                                                9.7
# 3                                                7.8
# 4                                               19.0
#
#    No. of abortions, by state of occurrence, 2020  \
# 0                                            5700
# 1                                            1240
# 2                                           13320
# 3                                            3250
# 4                                          154060
#
#   No. of abortions, by state of residence, 2020  \
# 0                                          9060
# 1                                          1320
# 2                                         13820
# 3                                          4510
# 4                                        152400
#
#    No. of federally funded abortions, 2010  \
# 0                                        9
# 1                                        0
# 2                                        1
# 3                                        0
# 4                                        0
#
#    No. of state funded abortions, 2010  \
# 0                                    0
# 1                                  835
# 2                                   13
# 3                                    0
# 4                                88466
#
#    Reported public expenditures for abortions (in 000s of dollars), federal, 2015  \
# 0                                                 22
# 1                                                  0
# 2                                                 28
# 3                                                  0
# 4                                                  0
#
#    Reported public expenditures for abortions (in 000s of dollars), state, 2015  \
# 0                                                  0
# 1                                                216
# 2                                                 11
# 3                                                  0
# 4                                              32613
#
#   Total no. of publicly funded abortions , 2010  \
# 0                                             9
# 1                                           835
# 2                                            14
# 3                                             0
# 4                                         88466
#
#    Total reported public expenditures for abortions (in 000s of dollars), 2015  \
# 0                                                 22
# 1                                                216
# 2                                                 40
# 3                                                  0
# 4                                              32613
#
#   Election2024
# 0   Republican
# 1   Republican
# 2   Republican
# 3   Republican
# 4     Democrat
#
# [5 rows x 32 columns]

# %%
import pandas as pd

# Create a dictionary to rename columns for easier plotting
rename_dict = {
    'U.S. State': 'state',
    '% change in abortion rate, 2017-2020': 'abortion_rate_change_pct',
    '% change in the no. of abortion clinics, 2017-2020': 'clinic_change_pct',
    '% change in the no. of abortion providers, 2014-2017': 'provider_change_pct',
    '% of all U.S. abortions, by state of occurrence, 2020': 'share_us_abortions',
    '% of counties without a known abortion provider, 2014': 'counties_no_provider_pct',
    '% of counties without a known clinic, 2020': 'counties_no_clinic_pct',
    '% of residents obtaining abortions who traveled out of state for care, 2020': 'out_of_state_pct',
    '% of women aged 15-44 living in a county without a clinic, 2020': 'women_no_clinic_pct',
    '% of women aged 15-44 living in a county without an abortion provider, 2014': 'women_no_provider_pct',
    'Abortion rate (the no. of abortions per 1,000 women aged 15-17), by state of residence, 2017': 'abortion_rate_15_17_2017',
    'Abortion rate (the no. of abortions per 1,000 women aged 15-19), by state of residence, 2017': 'abortion_rate_15_19_2017',
    'Abortion rate (the no. of abortions per 1,000 women aged 18-19), by state of residence, 2017': 'abortion_rate_18_19_2017',
    'Change in the no. of abortion clinics, 2017-2020': 'clinic_change',
    'Change in the no. of abortion providers, 2014-2017': 'provider_change',
    'No. of abortion clinics, 2020': 'num_clinics_2020',
    'No. of abortion providers, 2017': 'num_providers_2017',
    'No. of abortions among women aged 15-17, by state of residence, 2017': 'num_abortions_15_17_2017',
    'No. of abortions among women aged 15-19, by state of residence, 2017': 'num_abortions_15_19_2017',
    'No. of abortions among women aged 18-19, by state of residence, 2017': 'num_abortions_18_19_2017',
    'No. of abortions among women younger than 15, by state of residence, 2017': 'num_abortions_under15_2017',
    'No. of abortions per 1,000 women aged 15–44, by state of occurrence, 2020': 'abortions_per1000_occurrence_2020',
    'No. of abortions per 1,000 women aged 15–44, by state of residence, 2020': 'abortions_per1000_residence_2020',
    'No. of abortions, by state of occurrence, 2020': 'num_abortions_occurrence_2020',
    'No. of abortions, by state of residence, 2020': 'num_abortions_residence_2020',
    'No. of federally funded abortions, 2010': 'federal_abortions_2010',
    'No. of state funded abortions, 2010': 'state_abortions_2010',
    'Reported public expenditures for abortions (in 000s of dollars), federal, 2015': 'federal_expenditures_2015',
    'Reported public expenditures for abortions (in 000s of dollars), state, 2015': 'state_expenditures_2015',
    'Total no. of publicly funded abortions , 2010': 'total_public_abortions_2010',
    'Total reported public expenditures for abortions (in 000s of dollars), 2015': 'total_expenditures_2015',
    'Election2024': 'election_2024'
}

# Apply renaming
abortion = abortion.rename(columns=rename_dict)

# Check new column names
print(abortion.columns.tolist())
# Out:
# ['state', 'abortion_rate_change_pct', 'clinic_change_pct', 'provider_change_pct', 'share_us_abortions', 'counties_no_provider_pct', 'counties_no_clinic_pct', 'out_of_state_pct', 'women_no_clinic_pct', 'women_no_provider_pct', 'abortion_rate_15_17_2017', 'abortion_rate_15_19_2017', 'abortion_rate_18_19_2017', 'clinic_change', 'provider_change', 'num_clinics_2020', 'num_providers_2017', 'num_abortions_15_17_2017', 'num_abortions_15_19_2017', 'num_abortions_18_19_2017', 'num_abortions_under15_2017', 'abortions_per1000_occurrence_2020', 'abortions_per1000_residence_2020', 'num_abortions_occurrence_2020', 'num_abortions_residence_2020', 'federal_abortions_2010', 'state_abortions_2010', 'federal_expenditures_2015', 'state_expenditures_2015', 'total_public_abortions_2010', 'total_expenditures_2015', 'election_2024']

# %%
import altair as alt

# Convert % columns to numeric if they still contain strings
for col in ['women_no_clinic_pct', 'out_of_state_pct']:
    abortion[col] = (
        abortion[col]
        .astype(str)
        .str.replace('%', '', regex=False)
        .astype(float)
    )

# Create scatter plot
chart = (
    alt.Chart(abortion)
    .mark_circle(size=100)
    .encode(
        x=alt.X('women_no_clinic_pct:Q',
                title='Women aged 15–44 living in a county without a clinic (2020, %)'),
        y=alt.Y('out_of_state_pct:Q',
                title='Residents obtaining abortions out-of-state (2020, %)'),
        color=alt.Color('election_2024:N',
                        scale=alt.Scale(
                            domain=['Democrat', 'Republican'],
                            range=['#3b82f6', '#ef4444']
                        ),
                        title='2024 Election Result'),
        tooltip=['state', 'women_no_clinic_pct', 'out_of_state_pct', 'election_2024']
    )
    .properties(
        title='Women living in Republican states are travelling at higher rates to get abortions',
        width=600,
        height=400
    )
    .configure_axis(labelFontSize=12, titleFontSize=13)
    .configure_title(fontSize=16, anchor='start')
)

chart
# Out:
# alt.Chart(...)

# %%
import altair as alt

# Scatter plot: Clinic change vs. Abortion rate change by state
scatter_chart = (
    alt.Chart(abortion)
    .mark_circle(size=100)
    .encode(
        x=alt.X('clinic_change_pct:Q', title='Change in Number of Abortion Clinics (%)'),
        y=alt.Y('abortion_rate_change_pct:Q', title='Change in Abortion Rate (%)'),
        color=alt.Color('election_2024:N',
                        scale=alt.Scale(domain=['Democrat', 'Republican'],
                                        range=['#3b82f6', '#ef4444']),
                        title='2024 Election Result'),
        tooltip=['state', 'clinic_change_pct', 'abortion_rate_change_pct', 'election_2024']
    )
    .properties(
        width=600,
        height=400,
        title='Despite changes in the number of abortion clinics, abortion rates are staying the same in red and blue states'
    )
    .configure_axis(labelFontSize=12, titleFontSize=13)
    .configure_title(fontSize=16, anchor='start')
)

scatter_chart
# Out:
# alt.Chart(...)

# %%
slope_data = abortion.melt(
    id_vars=['state', 'election_2024'],
    value_vars=['abortions_per1000_residence_2020', 'abortions_per1000_occurrence_2020'],
    var_name='metric',
    value_name='value'
)

slope_chart = (
    alt.Chart(slope_data)
    .mark_line(point=True)
    .encode(
        x='metric:N',
        y='value:Q',
        detail='state:N',
        color=alt.Color('election_2024:N',
                        scale=alt.Scale(domain=['Democrat', 'Republican'],
                                        range=['#3b82f6', '#ef4444'])),
        tooltip=['state', 'metric', 'value', 'election_2024']
    )
    .properties(
        width=600,
        height=400,
        title='Residence vs Occurrence Abortion Rates by State (2020)'
    )
)

slope_chart
# Out:
# alt.Chart(...)

# %%
import altair as alt

# Create bar chart showing average out-of-state abortions by election
bar_chart = (
    alt.Chart(abortion)
    .mark_bar()
    .encode(
        x=alt.X('election_2024:N', title='2024 Election Result'),
        y=alt.Y('mean(out_of_state_pct):Q', title='Average % Out-of-State Abortions'),
        color=alt.Color('election_2024:N',
                        scale=alt.Scale(domain=['Democrat', 'Republican'],
                                        range=['#3b82f6', '#ef4444']),
                        legend=None),
        tooltip=[alt.Tooltip('election_2024:N', title='State Lean'),
                 alt.Tooltip('mean(out_of_state_pct):Q', title='Average % Out-of-State')]
    )
    .properties(
        title='Average Out-of-State Abortions by 2024 Election Result',
        width=400,
        height=300
    )
    .configure_axis(labelFontSize=12, titleFontSize=13)
    .configure_title(fontSize=16, anchor='start')
)

bar_chart
# Out:
# alt.Chart(...)

# %%
import altair as alt
from vega_datasets import data

# Load the map geometry for U.S. states
states = alt.topo_feature(data.us_10m.url, 'states')

# %%
import altair as alt
import pandas as pd
from vega_datasets import data

# Load US states topojson
states = alt.topo_feature(data.us_10m.url, 'states')

# Example: your abortion DataFrame already has these columns
# abortion.columns → ['U.S. State', 'No. of abortions per 1,000 women aged 15–44, by state of residence, 2020',
#                     '% of counties without a known abortion provider, 2014', 'Election2024']

# (optional) simplify column names for easier use
abortion = abortion.rename(columns={
    'U.S. State': 'State',
    'No. of abortions per 1,000 women aged 15–44, by state of residence, 2020': 'Abortions_per_1000',
    '% of counties without a known abortion provider, 2014': 'Percent_no_provider'
})

# --- Add FIPS codes (needed to link to the topojson) ---
# Mapping of state names to FIPS codes (50 states + DC)
state_fips = {
    "Alabama": 1, "Alaska": 2, "Arizona": 4, "Arkansas": 5, "California": 6,
    "Colorado": 8, "Connecticut": 9, "Delaware": 10, "District of Columbia": 11,
    "Florida": 12, "Georgia": 13, "Hawaii": 15, "Idaho": 16, "Illinois": 17,
    "Indiana": 18, "Iowa": 19, "Kansas": 20, "Kentucky": 21, "Louisiana": 22,
    "Maine": 23, "Maryland": 24, "Massachusetts": 25, "Michigan": 26,
    "Minnesota": 27, "Mississippi": 28, "Missouri": 29, "Montana": 30,
    "Nebraska": 31, "Nevada": 32, "New Hampshire": 33, "New Jersey": 34,
    "New Mexico": 35, "New York": 36, "North Carolina": 37, "North Dakota": 38,
    "Ohio": 39, "Oklahoma": 40, "Oregon": 41, "Pennsylvania": 42,
    "Rhode Island": 44, "South Carolina": 45, "South Dakota": 46, "Tennessee": 47,
    "Texas": 48, "Utah": 49, "Vermont": 50, "Virginia": 51, "Washington": 53,
    "West Virginia": 54, "Wisconsin": 55, "Wyoming": 56
}

abortion['id'] = abortion['State'].map(state_fips)

# --- Create choropleth map ---
chart = (
    alt.Chart(states)
    .mark_geoshape(stroke='white')
    .encode(
        color=alt.Color(
            'Abortions_per_1000:Q',
            scale=alt.Scale(scheme='blues'),
            title='Abortions per 1,000 Women (2020)'
        ),
        tooltip=[
            'State:N',
            'Abortions_per_1000:Q',
            'Percent_no_provider:Q',
            'Election2024:N'
        ]
    )
    .transform_lookup(
        lookup='id',
        from_=alt.LookupData(
            abortion,
            key='id',
            fields=['State', 'Abortions_per_1000', 'Percent_no_provider', 'Election2024']
        )
    )
    .project('albersUsa')
    .properties(
        width=700,
        height=450,
        title='Abortion Rate per 1,000 Women (2020) by State'
    )
)
chart
# Out:
# alt.Chart(...)

# %%
chart_election = (
    alt.Chart(states)
    .mark_geoshape(stroke='white')
    .encode(
        color=alt.Color(
            'Election2024:N',
            scale=alt.Scale(domain=['Democrat', 'Republican'],
                            range=['#3b82f6', '#ef4444']),
            title='2024 Election Result'
        ),
        tooltip=['State:N', 'Election2024:N']
    )
    .transform_lookup(
        lookup='id',
        from_=alt.LookupData(abortion, 'id', ['State', 'Election2024'])
    )
    .project('albersUsa')
    .properties(
        width=700,
        height=450,
        title='2024 U.S. Presidential Election by State'
    )
)
chart_election
# Out:
# alt.Chart(...)
